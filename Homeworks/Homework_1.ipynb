# %% [markdown]
# # Getting familiar with Data types and Visualization

# %% [markdown]
# 1.   Step 1: Download the dataset files belong to the following data formats from internet. The files may belong to any dataset available online.
# 2.   Step 2: Read these files inside the python code. Some of the file formats cannot be read using default python packages. In this case, explore the python packages suitable for reading the files.
# 3.   Step 3: Print the properties of the data files such as size, shape, dimensions, etc.
# 4.   Step 4: Visualize each of these data files using graphs, diagrams, etc.
#
#
# *    Table data visualization: line graph, bar graph, histogram chart, pie chart, scatter plot
# *    Image visualization: image plot, 3d plot
# *    Video visualization: video player
# *    Audio visualization: audio player, spectrogram
# *    Text visualization: Word cloud, bubble cloud (some more in http://vallandingham.me/textvis-talk/)

# %% [markdown]
# # Type 1
#
# ### Tabular, Spreadsheet and Interchange Data Formats
#
# *   "Table" — generic tabular data (.dat), "CSV" — comma-separated values (.csv), "TSV" — tab-separated values (.tsv), “ARFF” - Attribute-Relation File Format (.arff) – Read and visualize the data
# *   "XLS" — Excel spreadsheet (.xls), "XLSX" — Excel 2007 format (.xlsx), "ODS" — OpenDocument spreadsheet (.ods), "SXC" — OpenOffice 1.0 spreadsheet file (.sxc), "DIF" — VisiCalc data interchange format (.dif) – Read and visualize the data
# *   "JSON" — JavaScript Object Notation (.json), "UBJSON" — Universal Binary JSON (.ubj), “HTML” – Hypertext Markup Language (.html), “XML” - eXtensible Markup Language (.xml)  - Read and Parse the data

# %%
import pandas
import matplotlib.pyplot as plt
dataset= pandas.read_csv('train.csv')



print(dataset)
print(dataset.shape)


dataset.plot()
plt.figure()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]
# (2000, 21)

# %%
# Add your code here
dataexcel=pandas.read_excel("SampleData.xlsx")
print(dataexcel.shape)
dataexcel.plot()
plt.figure()
# Out:
# (21, 3)

# %%
# Add your code here

import json 
  
# Opening JSON file 
json = open('j.json',)

# %% [markdown]
# # Type 2
#
# ### Data File Formats
#
# *   PKL – Pickle format, HDF5, Zip, SQL, MAT, NPY, NPZ – Read and display the data

# %%
import numpy as np
import h5py

hf = h5py.File('uavmodel.h5', 'r')
hf.keys()
# Out:
# <KeysViewHDF5 []>

# %% [markdown]
# # Type 3
#
# ### Image Data Formats
# *   JPG, PNG, BMP, TIFF – Read and display the image
# *   3D medical Images: DICOM, MHA – Read and display the image

# %%
# Add your code here
import cv2
import matplotlib.pyplot as plt

img=cv2.imread("1.jpg")

plt.imshow(img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import pydicom as dicom
import matplotlib.pylab as plt

image_path = 'dicom.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array)

# %% [markdown]
# # Type 4
#
# ### Video Data Formats
# *   MP4, AVI, MPEG – Read and play the video

# %%
# Add your code here
import cv2
video=cv2.VideoCapture("iha.mp4")

while(True):
    # Capture frame-by-frame
    ret, frame = video.read()

    # Our operations on the frame come here
   

    # Display the resulting frame
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
video.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Type 5
#
# ### Audio Data Formats
# *   MP3, MIDI, WAV – Read and play the audio

# %%
# Add your code here
from playsound import playsound
playsound('audio.mp3')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-cbe8f1f3c24c> in <module>
#       1 # Add your code here
# ----> 2 from playsound import playsound
#       3 playsound('audio.mp3')
#
# ModuleNotFoundError: No module named 'playsound'

# %%
# Add your code here
import simpleaudio as sa

filename = 'audio.mp3'
wave_obj = sa.WaveObject.from_wave_file(filename)
play_obj = wave_obj.play()
play_obj.wait_done()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-a833cb2501ea> in <module>
#       1 # Add your code here
# ----> 2 import simpleaudio as sa
#       3
#       4 filename = 'audio.mp3'
#       5 wave_obj = sa.WaveObject.from_wave_file(filename)
#
# ModuleNotFoundError: No module named 'simpleaudio'

# %% [markdown]
# # Type 6
#
# ### Text Data Formats
#
# *   TXT, PDF, DOC – Read and parse the data

# %%
# Add your code here

f = open('metin.txt', 'r')
file_contents = f.read()
print (file_contents)
# Out:
# https://programindir.cafe/
# ki36461
# kubilay61
#
#
#
# https://zoom.us/j/93350784829?pwd=eFRVMW9IQVNnTzNsL0t4UnFQd05SQT09

# %%
# Add your code here

import PyPDF2 

pdfFileObj = open('1.pdf', 'rb') 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
print(pdfReader.numPages) 
pageObj = pdfReader.getPage(0) 
print(pageObj.extractText()) 
pdfFileObj.close()
# Out:
# 10
# 341 Yüksek L˜sans Ö˚renc˜s˜, Orta Do˚u Tekn˜k Ün˜vers˜tes˜ Havac˛l˛k ve Uzay Mühend˜sl˜˚˜ Bölümü Œ
# ata.adam@metu.edu.tr
# 2 Doç. Dr., Orta Do˚u Tekn˜k Ün˜vers˜tes˜ Havac˛l˛k ve Uzay Mühend˜sl˜˚˜ Bölümü Œ
# nuzol@metu.edu.tr
# 3 Türk Havac˛l˛k ve Uzay Sanay˜˜ A.˝. Hava Arac˛ Mühend˜sl˜˚˜
# - sercan.ertem@ta˜.com.tr
# 4 Dr., Türk Havac˛l˛k ve Uzay Sanay˜˜ A.˝. Hava Arac˛ Mühend˜sl˜˚˜
#  - eayan@ta˜.com.tr
# Ali Ata Adam
# 1, Nilay Sezer-Uzol2, Sercan Ertem3, Erdem Ayan
# 41. G˜R˜˚Alternat˜f kanat/gövde tasar˚mlar˚n˚n aerod˜nam˜k aç˚
# -s˚ndan h˚zl˚ b˜r ˛ek˜lde anal˜z ed˜lmes˜ uçak konsept ve
# ön tasar˚m a˛amalar˚nda büyük önem ta˛˚maktad˚r. Nav˜
# -er-Stokes denklemler˜n˜n çözümüne dayal˚ Hesaplamal˚
# Ak˚˛kanlar D˜nam˜˝˜ (HAD) s˜mülasyonlar˚, b˜rçok alter
# -nat˜f˜n h˚zl˚ b˜r b˜ç˜mde kar˛˚la˛t˚r˚lmas˚ gereken konsept
# ve ön tasar˚m a˛amalar˚nda oldukça yava˛ kalmaktad˚r.
# Buna alternat˜f olarak hem h˚zl˚ hem de do˝ruluk oran˚
# yüksek say˚lab˜len 3-boyutlu panel metodu öne ç˚kmak
# -tad˚r. Bu çal˚˛mada, uçak konsept tasar˚m a˛amas˚nda,
# kanat/gövde konf˜gürasyonlar˚n˚n ses alt˚ ve ses üstü
# h˚zlarda aerod˜nam˜k anal˜z˜ ˜ç˜n olu˛turulan hesaplamal˚
# aerod˜nam˜k anal˜z ve tasar˚m altyap˚s˚ ˜çer˜s˜nde, 3-bo
# -yutlu panel kodu kullan˚larak seç˜len kanat/gövde ˜k˜l˜s˜
# -n˜n aerod˜nam˜k performans˚ ˜ncelenm˜˛t˜r. Bu çal˚˛ma ˜le
# öncel˜kl˜ olarak, Boe˜ng ve NASA taraf˚ndan gel˜˛t˜r˜len,
# yüksek mertebel˜, 3-boyutlu, aç˚k kaynak, panel metodu
# çözücüsü PANAIR kodu temel al˚narak b˜r aerod˜nam˜k
# anal˜z altyap˚s˚ olu˛turulmu˛tur. Bu altyap˚, gerekl˜ ön ve
# art-˜˛lemler ˜ç˜n haz˚rlanan yard˚mc˚ kodlar ˜le desteklen
# -
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]
