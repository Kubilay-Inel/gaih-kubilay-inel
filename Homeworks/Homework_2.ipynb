# %% [markdown]
# ### Importing libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.datasets import mnist
from keras.models import Sequential,model_from_json
from keras.layers import Dense ,Dropout
from keras.optimizers import RMSprop,Adam
import pylab as plt

# %% [markdown]
# #### Keras is the deep learning library that helps you to code Deep Neural Networks with fewer lines of code

# %% [markdown]
# ### Import data

# %%
batch_size = 128
num_classes = 10
epochs = 2

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize to 0 to 1 range
x_train /= 255
x_test /= 255

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # Part 1: Analysis of Activation Functions

# %% [markdown]
# ### Try other Activation Functions
# Analyze the accuracy and training time
# #### Example Syntax
# * model.add(Dense(8, activation='tanh'))
# * model.add(Dense(8, activation='linear'))
# * model.add(Dense(8, activation='relu'))
# * model.add(Dense(8, activation='hard_sigmoid'))

# %% [markdown]
# ### Sigmoid Activation Function

# %%
model = Sequential()
model.add(Dense(64, activation='sigmoid', input_shape=(784,)))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.9343 - accuracy: 0.7983 - val_loss: 0.3669 - val_accuracy: 0.9125
# Epoch 2/10
# 469/469 [==============================] - 0s 1ms/step - loss: 0.3033 - accuracy: 0.9183 - val_loss: 0.2507 - val_accuracy: 0.9317
# Epoch 3/10
# 469/469 [==============================] - 0s 1ms/step - loss: 0.2266 - accuracy: 0.9368 - val_loss: 0.2054 - val_accuracy: 0.9418
# Epoch 4/10
# 469/469 [==============================] - 0s 1ms/step - loss: 0.1853 - accuracy: 0.9474 - val_loss: 0.1739 - val_accuracy: 0.9499
# Epoch 5/10
# 469/469 [==============================] - 0s 1ms/step - loss: 0.1567 - accuracy: 0.9551 - val_loss: 0.1526 - val_accuracy: 0.9545
# Epoch 6/10
# 469/469 [==============================] - 0s 1ms/step - loss: 0.1348 - accuracy: 0.9614 - val_loss: 0.1348 - val_accuracy: 0.9611
# Epoch 7/10
# 469/469 [==============================] - 0s 1ms/step - loss: 0.1174 - accuracy: 0.9663 - val_loss: 0.1262 - val_accuracy: 0.9639
# Epoch 8/10
# 469/469 [==============================] - 0s 1ms/step - loss: 0.1035 - accuracy: 0.9703 - val_loss: 0.1190 - val_accuracy: 0.9655
# Epoch 9/10
# 469/469 [==============================] - 0s 1ms/step - loss: 0.0919 - accuracy: 0.9739 - val_loss: 0.1078 - val_accuracy: 0.9676
# Epoch 10/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0824 - accuracy: 0.9765 - val_loss: 0.1027 - val_accuracy: 0.9696
# Test loss: 0.1026640385389328
# Test accuracy: 0.9696000218391418

# %% [markdown]
# ### Relu Activation Function

# %%
# Write your code here. Use the same architecture as above. 
model = Sequential()


model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3830 - accuracy: 0.8934 - val_loss: 0.1855 - val_accuracy: 0.9447
# Epoch 2/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1628 - accuracy: 0.9522 - val_loss: 0.1383 - val_accuracy: 0.9568
# Epoch 3/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1216 - accuracy: 0.9644 - val_loss: 0.1142 - val_accuracy: 0.9657
# Epoch 4/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0973 - accuracy: 0.9709 - val_loss: 0.1038 - val_accuracy: 0.9677
# Epoch 5/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0805 - accuracy: 0.9759 - val_loss: 0.0955 - val_accuracy: 0.9704
# Epoch 6/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0693 - accuracy: 0.9790 - val_loss: 0.0959 - val_accuracy: 0.9709
# Epoch 7/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0588 - accuracy: 0.9827 - val_loss: 0.0917 - val_accuracy: 0.9719
# Epoch 8/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0525 - accuracy: 0.9841 - val_loss: 0.0864 - val_accuracy: 0.9735
# Epoch 9/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0457 - accuracy: 0.9860 - val_loss: 0.0864 - val_accuracy: 0.9735
# Epoch 10/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0404 - accuracy: 0.9879 - val_loss: 0.0940 - val_accuracy: 0.9733
# Test loss: 0.09398851543664932
# Test accuracy: 0.9732999801635742

# %%
model = Sequential()
model.add(Dense(64, activation='tanh', input_shape=(784,)))
model.add(Dense(64, activation='tanh'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3886 - accuracy: 0.8920 - val_loss: 0.2195 - val_accuracy: 0.9360
# Epoch 2/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1817 - accuracy: 0.9464 - val_loss: 0.1502 - val_accuracy: 0.9562
# Epoch 3/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1303 - accuracy: 0.9624 - val_loss: 0.1239 - val_accuracy: 0.9631
# Epoch 4/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1019 - accuracy: 0.9696 - val_loss: 0.1053 - val_accuracy: 0.9682
# Epoch 5/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0824 - accuracy: 0.9758 - val_loss: 0.0989 - val_accuracy: 0.9684
# Epoch 6/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0688 - accuracy: 0.9797 - val_loss: 0.0899 - val_accuracy: 0.9730
# Epoch 7/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0581 - accuracy: 0.9824 - val_loss: 0.0906 - val_accuracy: 0.9731
# Epoch 8/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0490 - accuracy: 0.9856 - val_loss: 0.0819 - val_accuracy: 0.9753
# Epoch 9/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0416 - accuracy: 0.9879 - val_loss: 0.0944 - val_accuracy: 0.9723
# Epoch 10/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0354 - accuracy: 0.9895 - val_loss: 0.0910 - val_accuracy: 0.9726
# Test loss: 0.09103363752365112
# Test accuracy: 0.972599983215332

# %%
model = Sequential()
model.add(Dense(64, activation='linear', input_shape=(784,)))
model.add(Dense(64, activation='linear'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4105 - accuracy: 0.8821 - val_loss: 0.3114 - val_accuracy: 0.9111
# Epoch 2/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2937 - accuracy: 0.9176 - val_loss: 0.2804 - val_accuracy: 0.9218
# Epoch 3/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2799 - accuracy: 0.9210 - val_loss: 0.2868 - val_accuracy: 0.9205
# Epoch 4/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2749 - accuracy: 0.9237 - val_loss: 0.2856 - val_accuracy: 0.9189
# Epoch 5/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2693 - accuracy: 0.9251 - val_loss: 0.2858 - val_accuracy: 0.9199
# Epoch 6/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2685 - accuracy: 0.9249 - val_loss: 0.2825 - val_accuracy: 0.9215
# Epoch 7/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2641 - accuracy: 0.9258 - val_loss: 0.2881 - val_accuracy: 0.9191
# Epoch 8/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2638 - accuracy: 0.9270 - val_loss: 0.2920 - val_accuracy: 0.9183
# Epoch 9/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2591 - accuracy: 0.9269 - val_loss: 0.2827 - val_accuracy: 0.9211
# Epoch 10/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2595 - accuracy: 0.9264 - val_loss: 0.2882 - val_accuracy: 0.9226
# Test loss: 0.28821036219596863
# Test accuracy: 0.9225999712944031

# %% [markdown]
# ### Write your findings about activations here?
#
# 1.   Relu and Tanh activations is more accuracy than sigmoid and linear
# 2.   Relu is best activation for this dataset

# %% [markdown]
# # Part 2: Design Choices: Nodes
# #### Analyze the parameter size, accuracy and training time

# %% [markdown]
# ### Design a model with small Number of Nodes. For Example 8

# %%
first_layer_size = 16

model = Sequential()
model.add(Dense(first_layer_size, activation='sigmoid', input_shape=(784,)))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))
model.add(Dropout(0.25))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

w = []
for layer in model.layers:
    weights = layer.get_weights()
    w.append(weights)

layer1 = np.array(w[0][0])
print("Shape of First Layer",layer1.shape)
print("Visualization of First Layer")

import matplotlib.pyplot as plt
fig=plt.figure(figsize=(16, 16))
columns = 8
rows = int(first_layer_size/8)
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(layer1[:,i-1].reshape(28,28),cmap='gray')
plt.show()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_61 (Dense)             (None, 16)                12560
# _________________________________________________________________
# dense_62 (Dense)             (None, 64)                1088
# _________________________________________________________________
# dense_63 (Dense)             (None, 10)                650
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_64 (Dense)             (None, 32)                352
# _________________________________________________________________
# dense_65 (Dense)             (None, 10)                330
# =================================================================
# Total params: 14,980
# Trainable params: 14,980
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1529 - accuracy: 0.1691 - val_loss: 1.9388 - val_accuracy: 0.2099
# Epoch 2/2
# 469/469 [==============================] - 1s 2ms/step - loss: 1.9425 - accuracy: 0.1819 - val_loss: 1.8266 - val_accuracy: 0.2101
# Test loss: 1.8266490697860718
# Test accuracy: 0.210099995136261
# Shape of First Layer (784, 16)
# Visualization of First Layer

# %% [markdown]
# ### Design a model with large Number of Nodes. For example 128

# %%
# Write your code here 

# Use the same layer design from the above cell. Play with the parameter "first_layer_size" above. 
# It is preferred to have first_layer_size as multiplication of 8 (for visualizing the weights properly)

# %%
first_layer_size = 128

model = Sequential()
model.add(Dense(first_layer_size, activation='sigmoid', input_shape=(784,)))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))
model.add(Dropout(0.25))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

w = []
for layer in model.layers:
    weights = layer.get_weights()
    w.append(weights)

layer1 = np.array(w[0][0])
print("Shape of First Layer",layer1.shape)
print("Visualization of First Layer")

import matplotlib.pyplot as plt
fig=plt.figure(figsize=(16, 16))
columns = 8
rows = int(first_layer_size/8)
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(layer1[:,i-1].reshape(28,28),cmap='gray')
plt.show()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_67 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_68 (Dense)             (None, 10)                650
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_69 (Dense)             (None, 32)                352
# _________________________________________________________________
# dense_70 (Dense)             (None, 10)                330
# =================================================================
# Total params: 110,068
# Trainable params: 110,068
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 469/469 [==============================] - 1s 2ms/step - loss: 2.1324 - accuracy: 0.2249 - val_loss: 1.8381 - val_accuracy: 0.3062
# Epoch 2/2
# 469/469 [==============================] - 1s 2ms/step - loss: 1.7603 - accuracy: 0.2546 - val_loss: 1.5336 - val_accuracy: 0.3090
# Test loss: 1.5335736274719238
# Test accuracy: 0.3089999854564667
# Shape of First Layer (784, 128)
# Visualization of First Layer

# %% [markdown]
# ### Write your findings about influence of nodes here?
#
# 1.   Learning rate is increasing with layers and loss is decrease but more layers will be slower model

# %% [markdown]
# # Part 3: Design Choices: Layers
# #### Analyze the parameter size, accuracy and training time

# %% [markdown]
# ### Design a model with small number of layers. For example 1 hidden layer

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(784,)))

model.add(Dense(32, activation='relu', input_shape=(784,)))
model.add(Dense(32, activation='relu', input_shape=(784,)))


model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_71 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_72 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_73 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_74 (Dense)             (None, 10)                330
# =================================================================
# Total params: 53,706
# Trainable params: 53,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4284 - accuracy: 0.8760 - val_loss: 0.2228 - val_accuracy: 0.9331
# Epoch 2/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1875 - accuracy: 0.9439 - val_loss: 0.1612 - val_accuracy: 0.9525
# Epoch 3/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1407 - accuracy: 0.9582 - val_loss: 0.1429 - val_accuracy: 0.9577
# Epoch 4/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1136 - accuracy: 0.9663 - val_loss: 0.1205 - val_accuracy: 0.9621
# Epoch 5/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0964 - accuracy: 0.9711 - val_loss: 0.1104 - val_accuracy: 0.9671
# Epoch 6/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0822 - accuracy: 0.9753 - val_loss: 0.1194 - val_accuracy: 0.9633
# Epoch 7/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0739 - accuracy: 0.9778 - val_loss: 0.1046 - val_accuracy: 0.9683
# Epoch 8/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0650 - accuracy: 0.9806 - val_loss: 0.1015 - val_accuracy: 0.9696
# Epoch 9/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0575 - accuracy: 0.9825 - val_loss: 0.1045 - val_accuracy: 0.9687
# Epoch 10/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0510 - accuracy: 0.9843 - val_loss: 0.1104 - val_accuracy: 0.9689
# Test loss: 0.11043521761894226
# Test accuracy: 0.9689000248908997

# %% [markdown]
# ### Lower number of Layers. For example 4 hidden layers

# %%
# Write your code here 

# Use the same number of units from the above cell

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(784,)))

model.add(Dense(32, activation='relu', input_shape=(784,)))
model.add(Dense(32, activation='relu', input_shape=(784,)))
model.add(Dense(16, activation='relu', input_shape=(784,)))
model.add(Dense(16, activation='relu', input_shape=(784,)))

model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_75 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_76 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_77 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_78 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_79 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_80 (Dense)             (None, 10)                170
# =================================================================
# Total params: 54,346
# Trainable params: 54,346
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5797 - accuracy: 0.8258 - val_loss: 0.2561 - val_accuracy: 0.9237
# Epoch 2/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.2114 - accuracy: 0.9373 - val_loss: 0.1818 - val_accuracy: 0.9460
# Epoch 3/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1518 - accuracy: 0.9553 - val_loss: 0.1837 - val_accuracy: 0.9440
# Epoch 4/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1217 - accuracy: 0.9640 - val_loss: 0.1206 - val_accuracy: 0.9633
# Epoch 5/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.1018 - accuracy: 0.9690 - val_loss: 0.1233 - val_accuracy: 0.9659
# Epoch 6/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0880 - accuracy: 0.9735 - val_loss: 0.1363 - val_accuracy: 0.9623
# Epoch 7/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0781 - accuracy: 0.9766 - val_loss: 0.1194 - val_accuracy: 0.9667
# Epoch 8/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0702 - accuracy: 0.9790 - val_loss: 0.1029 - val_accuracy: 0.9704
# Epoch 9/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0632 - accuracy: 0.9804 - val_loss: 0.1136 - val_accuracy: 0.9682
# Epoch 10/10
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0570 - accuracy: 0.9827 - val_loss: 0.1083 - val_accuracy: 0.9700
# Test loss: 0.10830426216125488
# Test accuracy: 0.9700000286102295

# %% [markdown]
# ### Write your findings about influence of layers here?
#
# 1.   Finding 1
# 2.   Finding 2
